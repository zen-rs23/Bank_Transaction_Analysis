# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/MLAA_Assignment3_Group5/mlaa_a3_merged_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-1eb43b173ba7> in <cell line: 1>()
# ----> 1 df = pd.read_csv('/content/drive/MyDrive/MLAA_Assignment3_Group5/mlaa_a3_merged_data.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
pd.set_option('display.max_columns', 100)
df.sample(15)
# Out:
#                  cc_num_x      acct_num                         trans_num  \
# 3508799  4894204664896676  860928862867  d9d9483197fa0ba9e578128abf981c2d
# 3539456  4570900163564076  715198687055  1453a115f0fee8125239115c28a8d946
# 1847411  6011310890714014  639730188719  820d44e38da01b2ca701852097c30603
# 2818226  6539385258001066   95004578288  799e162065e2687c7778bcd30eb1549e
# 3897244  6580085294690215  870993336751  aefa10a53f8f61ee327a7c5396ea7eab
# 1561348  6011851744600453  976324714626  abe89f46e225163b79e5e13152c272cb
# 3427496  3532961512048509  683359666188  06d0c0d643a60c8e385bf4ca7ce8fc9a
# 3704491  4058416806134954  682282682147  e2168eef913dbcad77e2623a136b93c7
# 2423581  3504389836403768  401239553647  cef9f49f83b77eb7487ee285fc14d3df
# 2079472     4603754821459  750737122054  864bc9d8002283f92f9614dfc5dad7a1
# 3421724    30391900889913  502226927571  57ab3d66731ef66b03c77b5b927fa557
# 1362590   213146337861375   36140245674  3716156c95deecefb49dfe93031a5d80
# ...

# %%
# Create two dataframes with fraud and non-fraud data 
df_fraud = data.loc[data.is_fraud == 1] 
df_non_fraud = data.loc[data.is_fraud == 0]

sns.countplot(x="is_fraud",data=data)
plt.title("Count of Fraudulent Payments")
plt.show()
print("Number of normal examples: ",df_non_fraud.is_fraud.count())
print("Number of fradulent examples: ",df_fraud.is_fraud.count())
#print(data.fraud.value_counts()) # does the same thing above
